# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

arr = pd.read_csv('eeg.csv')
firstCol = arr.iloc[:,4]
print(firstCol)
print(firstCol.max())
#plt.boxplot(firstCol)
#plt.boxplot(arr)

plot = plt.boxplot(arr)
plt.ylim(0,6000)
# Out:
# 0       4342.05
# 1       4336.92
# 2       4343.59
# 3       4347.69
# 4       4345.64
#          ...
# 9394    4338.97
# 9395    4336.92
# 9396    4340.00
# 9397    4334.36
# 9398    4333.33
# Name: 4350.26, Length: 9399, dtype: float64
# 6474.36
# (0.0, 6000.0)
